# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('C:/Users/zubel/OneDrive/Documentos/GitHub/Portfolio-FZ/Python/ETL - Cars/CarsDatasetOrig.csv', encoding='latin1')

# %%
df
# Out:
#      Company Names         Cars Names                    Engines  \
# 0          FERRARI      SF90 STRADALE                         V8
# 1      ROLLS ROYCE            PHANTOM                        V12
# 2             Ford                KA+                1.2L Petrol
# 3         MERCEDES            GT 63 S                         V8
# 4             AUDI         AUDI R8 Gt                        V10
# ...            ...                ...                        ...
# 1208         Mazda        Bongo Truck              2.0L Inline-4
# 1209         Mazda      Rotary Pickup  1.3L Wankel Rotary Engine
# 1210         Mazda  Luce Rotary Coupe  1.3L Wankel Rotary Engine
# 1211         Mazda         Millenia S                    2.5L V6
# 1212         Mazda    787B (Race Car)  2.6L Wankel Rotary Engine
#
#      CC/Battery Capacity HorsePower Total Speed Performance(0 - 100 )KM/H  \
# 0                3990 cc     963 hp    340 km/h                   2.5 sec
# ...

# %%
df["Torque"].unique()
# Out:
# array(['800 Nm', '900 Nm', '100 - 140 Nm', '560 Nm', '770 Nm', '685 Nm',
#        '690 Nm', '718 Nm', '760 Nm', '719 Nm', '500 Nm', '205 Nm',
#        '250 Nm', '651 Nm', '637 Nm', '366 Nm', '475 Nm', '380 Nm',
#        '354 Nm', '240 Nm', '270 Nm', '351 Nm', '381 Nm', '1000 Nm',
#        '700 Nm', '630 Nm', '821 Nm', '720 Nm', '600 Nm', '850 Nm',
#        '565 Nm', '870 Nm', '520 Nm', '620 Nm', '950 Nm', '750 Nm',
#        '650 Nm', '550 Nm', '840 Nm', '400 Nm', '664 Nm', '570 Nm',
#        '220 Nm', '450 Nm', '280 Nm', '200 Nm', '300 Nm', '350 Nm',
#        '370 Nm', '360 Nm', '142 Nm', '335 Nm', '150 Nm', '330 Nm',
#        '145 Nm', '120 Nm', '320 Nm', '113 Nm', '130 Nm', '93 Nm',
#        '340 Nm', '390 Nm', '420 Nm', '356 Nm', '355 Nm', '151 Nm',
#        '395 Nm', '264 Nm', '295 Nm', '175 Nm', '310 Nm', '95 Nm',
#        '385 Nm', '460 Nm', '410 Nm', '245 Nm', '132 Nm', '106 Nm',
#        '153 Nm', '290 Nm', '580 Nm', '170 Nm', '230 Nm', '210 Nm',
# ...
